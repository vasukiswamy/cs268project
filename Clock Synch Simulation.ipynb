# %%
# %matplotlib inline
import random
import numpy as np
import matplotlib.pyplot as plt
import math


class Client:

    def __init__(self, id_num, alpha, beta, dist, real_model, GHz, t0, duration):
        self.id = id_num
        self.alpha = alpha
        self.beta = beta
        self.delay = dist / (3.0 * 10**8)
        self.total_error = 0.0
        self.frequency = GHz * 10.0**9  # in Hertz now
        self.real_model = real_model  # if True use the realistic model
        self.noise = []

        if real_model:
            prev_sum = 0.0
            sigma = math.sqrt(int(t0 * self.frequency)) * 0.0005 / self.frequency

            # element m in array is the sum of n(1) to n(m)
            for i in range(int(duration/t0)):
                prev_sum += np.random.normal(0, sigma)
                self.noise.append(prev_sum)

        # Variables to be calculated
        # virtual is the first virtual time received - C(t + .... )
        # t0 will be the interval for beacon (sent in first msg)
        self.alpha_est, self.beta_est, self.t0, self.first_clock = (None,) * 4

    # this will save the alpha/beta/noise values
    def reset(self):
        self.total_error = 0.0

    # calculates C(t) = a * t + b
    # kth time interval for real_model
    def get_clock_time(self, t, k=1):
        if self.real_model:
            return (self.alpha * t + self.beta + self.noise[int(k-1)])
        else:
            return self.alpha * t + self.beta

    # what the client clock synchs to
    # kth time interval for real_model
    def get_virtual_time(self, t, k):
        return (self.get_clock_time(t, k) - self.beta_est) / (self.alpha_est)

    # Receives the first/second synchronization and stores it
    def recv_synch(self, t, t0):
        self.first_clock = self.get_clock_time(t, 1)
        self.t0 = t0

    # uses first and last value
    def update_values(self, iteration, t):
        # Subtract iter by 1 bc the first iter does nothing
        self.alpha_est = (self.get_clock_time(t, iteration) - self.first_clock) / (self.t0 * (iteration-1))
        self.beta_est = self.get_clock_time(t, iteration) - self.alpha_est * t

    # uses second to last value
    def update_values_last(self, t, iteration, prev_time):
        self.alpha_est = (self.get_clock_time(t, iteration) - prev_time) / (self.t0)
        self.beta_est = self.get_clock_time(t, iteration) - self.alpha_est * t


class System:

    # t0 is in seconds
    def __init__(self, t0):
        self.num_clients = 0
        self.t0 = t0
        self.current_interval = 0

        # estimated time at time i
        self.estimated_times = {}
        self.real_times = {}

        # key is id; value is client object
        self.clients = {}

    # d is the distance from the master
    def add_client(self, id_num, alpha, beta, dist, real_model, GHz=10, t0=0.001, duration=100):
        self.clients[id_num] = Client(id_num, alpha, beta, dist, real_model, GHz, t0, duration)
        self.estimated_times[id_num] = []
        self.real_times[id_num] = []
        self.num_clients += 1

    # Drifts the clocks a certain number of intervals
    # only call drift once in the beginning for now
    # not sure if calling this later will mess up current_interval for calculations of a, b
    # I think it's ok but not 100% sure
    def drift(self, num_intervals):
        t0 = self.t0
        for i in range(num_intervals):
            for k in range(1, self.num_clients+1):
                # For client k
                # add the client's real time wrt t0* current interval
                self.estimated_times[k].append(self.clients[k].get_clock_time(self.current_interval*t0))
                self.real_times[k].append(self.current_interval*t0)
            self.current_interval += 1

    # starts the synchronization on current interval time
    # only call this once for now
    def start_synch(self, num_times, first=True, sigma=0.01, lambda_constant=1, store=False, k_distr=np.random.normal):
        t0 = self.t0
        mean = 0  # this is assumed
        iteration = 1  # stores the interval when updating; ease of use for calculations b/c of drift

        # First time no update
        # Simulate by drifting 1 interval for purposes of graph
        self.drift(1)

        # used for bad method
        prev_time = {}

        for k in range(1, self.num_clients+1):
            t = self.current_interval * t0 + self.clients[k].delay + lambda_constant * k_distr(mean, sigma)
            self.clients[k].recv_synch(t, t0)
            prev_time[k] = self.clients[k].first_clock

        iteration += 1
        self.current_interval += 1

        # Start updating
        for i in range(num_times-1):
            for k in range(1, self.num_clients+1):
                t = self.current_interval * t0 + self.clients[k].delay + lambda_constant * k_distr(mean, sigma)

                # Update alpha and beta
                if not first:
                    self.clients[k].update_values_last(t, iteration, prev_time[k])
                    prev_time[k] = self.clients[k].get_clock_time(t, iteration)
                else:
                    self.clients[k].update_values(iteration, t)

                # Calculations for graphs
                real_time = self.current_interval * t0
                est_time = self.clients[k].get_virtual_time(self.current_interval * t0, iteration)

                if store:
                    self.estimated_times[k].append(est_time)
                    self.real_times[k].append(real_time)
                else:  # summing for average
                    self.clients[k].total_error += abs(est_time - real_time)

            iteration += 1
            self.current_interval += 1

    # Create graph for all time intervals
    def create_graph(self, interval=None):
        if interval:
            intervals = range(interval, len(self.estimated_times[1]))
        else:
            interval = 0
            intervals = range(len(self.estimated_times[1]))

        for i in range(1, 5):
            plt.plot(intervals, abs(np.array(self.estimated_times[i])[interval:] - np.array(self.real_times[i])[interval:]), label='Client ' + str(i))
        plt.legend(loc='upper right')
        plt.ylabel('Difference between estimated and real time')
        plt.xlabel('Time interval')
        plt.show()

    def average_error(self, client_id):
        # interval will always be one more
        # first synch step does nothing/has no error
        return self.clients[client_id].total_error/(self.current_interval - 1)

    # For adding new clocks
    # same as init function
    def reset_system(self):
        self.num_clients = 0
        self.current_interval = 0
        self.estimated_times = {}
        self.real_times = {}
        self.clients = {}

    # does not delete clocks
    def reset_part_system(self):
        self.current_interval = 0

        for i in self.estimated_times.keys():
            self.estimated_times[i] = []
        for i in self.real_times.keys():
            self.real_times[i] = []

    # time is in seconds
    def create_graph_diff_alpha(self, ppm, step, time, frequency, real_model=False, beta=0.000000003, distance=2.2):
        ppm = ppm/10.0**6
        alpha_values = np.arange(1-ppm, 1+ppm+step, step)  # arange endpoint not inclusive
        num_intervals = int(time/self.t0)  # number of time intervals to run
        results = []

        # Get average longtime error for one alpha value
        for alpha in alpha_values:
            self.reset_system()
            system.add_client(1, alpha, beta, distance, real_model, frequency)
            system.start_synch(num_intervals, first=True, sigma=1, lambda_constant=200e-9, store=False)  # use first clock
            results.append(self.average_error(1))
        plt.stem(alpha_values, results)
        plt.ylabel('Average Longtime Error')
        plt.xlabel('Skew or Alpha Value')
        plt.show()

    # Assumes that the real clock model is always used
    def create_compare_first_consecutive(self, ppm, step, time, frequency, beta=0.000000003, distance=2.2):
        ppm = ppm/10.0**6
        alpha_values = np.arange(1-ppm, 1+ppm+step, step)  # arange endpoint not inclusive
        num_intervals = int(time/self.t0)  # number of time intervals to run
        results_first = []  # use first time
        results_last = []  # use second to last time
        real_model = True  # Always use real clock model

        # Get average longtime error for one alpha value
        for alpha in alpha_values:
            self.reset_system()
            system.add_client(1, alpha, beta, distance, real_model, frequency)

            # Use the first clock time
            system.start_synch(num_intervals, first=True, sigma=1, lambda_constant=200e-9, store=False)  # use first clock
            results_first.append(self.average_error(1))

            # Use the second to last clock time
            self.reset_part_system()
            self.clients[1].reset()

            system.start_synch(num_intervals, first=False, sigma=1, lambda_constant=200e-9, store=False)  # use second to last clock
            results_last.append(self.average_error(1))
        print "Errors with second to last"
        print results_last
        print "Errors with first"
        print results_first

# %%
# Constants

t0 = 0.001 # length of interval; 1 ms
noise_sigma = 1 # for distr of noise
alpha_ppm = 300
frequency = 10 # Ghz
duration = 100 # seconds
default_model = True # using first clocktime

# %%
# Initialize
system = System(t0)

# Add some nodes
# id, alpha, beta, distance in meters
system.add_client(1, 0.999999776296498, 0.000000003, 2.2, False)
system.add_client(2, 1.000000141952192, 0.000000001, 2.6, False)
system.add_client(3, 0.999999877467404, 0.000000009, 3.9, False)
system.add_client(4, 0.99999971401255, 0.000000008, 3.1, False)

# Allow clocks to drift 60 intervals
system.drift(60)

# Start synchronization for 50 intervals
system.start_synch(50,default_model, noise_sigma, 200e-9, True)

system.create_graph()
system.create_graph(60)
system.create_graph(70)

# %%
# Initialize
t0 = 0.0000001 # length of interval; 0.1 microsecond
system = System(t0)

# Add some nodes
# id, alpha, beta, distance in meters
system.add_client(1, 0.999999776296498, 0.000000003, 2.2, False)
system.add_client(2, 1.000000141952192, 0.000000001, 2.6, False)
system.add_client(3, 0.999999877467404, 0.000000009, 3.9, False)
system.add_client(4, 0.99999971401255, 0.000000008, 3.1, False)

# Allow clocks to drift 60 intervals
system.drift(60)

# Start synchronization for 50 intervals
system.start_synch(50,default_model, noise_sigma, 200e-9, True)

system.create_graph()
system.create_graph(60)
system.create_graph(70)

# %%
# Initialize
t0 = 0.01 # length of interval; 10 ms
system = System(t0)

# Add some nodes
# id, alpha, beta, distance in meters
system.add_client(1, 0.999999776296498, 0.000000003, 2.2, False)
system.add_client(2, 1.000000141952192, 0.000000001, 2.6, False)
system.add_client(3, 0.999999877467404, 0.000000009, 3.9, False)
system.add_client(4, 0.99999971401255, 0.000000008, 3.1, False)

# Allow clocks to drift 60 intervals
system.drift(60)

# Start synchronization for 50 intervals
system.start_synch(50,default_model, noise_sigma, 200e-9, True)

system.create_graph()
system.create_graph(60)
system.create_graph(70)

# %%
# Initialize
system = System(t0)

# ppm, step size for alpha, duration in seconds

system.create_graph_diff_alpha(alpha_ppm, 10.0**(-6), 50, frequency, real_model=False, beta=0.000000003, distance=2.2)

# %%
# Initialize
system = System(t0)

# ppm, step size for alpha, duration in seconds
system.create_graph_diff_alpha(alpha_ppm, 10.0**(-6), 50, frequency, real_model=True, beta=0.000000003, distance=2.2)

# %%
# Initialize
system = System(t0)

system.create_compare_first_consecutive(alpha_ppm, 10.0**(-6), 50, frequency, beta=0.000000003, distance=2.2)
# Out:
# Errors with second to last
# [4.4310482338882903e-12, 4.5369912174408887e-12, 4.6647192893101151e-12, 4.6955109821167354e-12, 4.6389957965298213e-12, 4.3977714338228055e-12, 4.5344724600160372e-12, 4.6762917885190266e-12, 4.4774788640622455e-12, 4.6558581337508011e-12, 4.3936660018562001e-12, 4.6361043046228011e-12, 4.4323638731524894e-12, 4.4602973620078146e-12, 4.546396251137175e-12, 4.4164204800190009e-12, 4.5217751550030716e-12, 4.473396022358633e-12, 4.5393646390390342e-12, 4.5563913586565971e-12, 4.509073665143193e-12, 4.6361476400968996e-12, 4.727050038899616e-12, 4.5668600456849617e-12, 4.4098808799075688e-12, 4.5039823898251895e-12, 4.5611075999429928e-12, 4.4862995367267458e-12, 4.4047324572471512e-12, 4.4902260507018176e-12, 4.5375283676263313e-12, 4.4895212263085241e-12, 4.4862036759074629e-12, 4.6737767017690502e-12, 4.5293886169472945e-12, 4.6201118354682881e-12, 4.624985017187555e-12, 4.3229612049777713e-12, 4.447349997299677e-12, 4.2946920290887204e-12, 4.5090283305737607e-12, 4.7331710988085533e-12, 4.4584486463827847e-12, 4.4097049546609755e-12, 4.5045540165988832e-12, 4.6164884512367446e-12, 4.5334236024874298e-12, 4.4950428025603003e-12, 4.4562066821296484e-12, 4.4812874917810054e-12, 4.3646134310904031e-12, 4.4427345198549961e-12, 4.4315607808376177e-12, 4.682120444826632e-12, 4.6749480099583798e-12, 4.5212655071236176e-12, 4.6955148505500868e-12, 4.7427584047576858e-12, 4.4730340799381539e-12, 4.6226905608959258e-12, 4.6012052480615128e-12, 4.624199474723145e-12, 4.6082540311465079e-12, 4.4727136896960393e-12, 4.6620555999021818e-12, 4.4201344910621554e-12, 4.7131158371904737e-12, 4.5111869059755173e-12, 4.6011344047303118e-12, 4.5180136645783795e-12, 4.4298273771392619e-12, 4.5209160901005244e-12, 4.5888895912338242e-12, 4.4659546560854581e-12, 4.4573129284741777e-12, 4.6319478252954128e-12, 4.5758947207763525e-12, 4.6110490953266134e-12, 4.5172531021320242e-12, 4.5985511704094153e-12, 4.6342072693161818e-12, 4.6283024246474015e-12, 4.5814455833237403e-12, 4.5680700687389383e-12, 4.5913378800277456e-12, 4.4291970702214912e-12, 4.3235548939646314e-12, 4.4253450966202926e-12, 4.5168355319868956e-12, 4.6599859637730394e-12, 4.5009646683358276e-12, 4.6944903839274408e-12, 4.6748694172704664e-12, 4.5428564771077264e-12, 4.650581374165963e-12, 4.7591999681462215e-12, 4.6166261674640551e-12, 4.3710844943589677e-12, 4.4919026276346585e-12, 4.4916135734374143e-12, 4.4798161562276118e-12, 4.6524803273828571e-12, 4.5239110742223421e-12, 4.3778286044904305e-12, 4.4325176293269483e-12, 4.6643047556249592e-12, 4.6993691063534902e-12, 4.4297196861997622e-12, 4.6096074388102257e-12, 4.6099626969942076e-12, 4.6042789338118788e-12, 4.5097275309935457e-12, 4.4594633777372824e-12, 4.4816394692559487e-12, 4.6687637443587612e-12, 4.5047613056459215e-12, 4.6131068007215779e-12, 4.6872549931686876e-12, 4.4133627093156936e-12, 4.3624587539592419e-12, 4.5493419253972434e-12, 4.5336337801960005e-12, 4.6410968741750217e-12, 4.4495902261354467e-12, 4.6079517007635573e-12, 4.6673365457217118e-12, 4.4727718140347153e-12, 4.7442110552575743e-12, 4.5865509119835665e-12, 4.509955835868551e-12, 4.6736037186134729e-12, 4.2582431393489717e-12, 4.5637637162421199e-12, 4.4991613865064115e-12, 4.4294201570482808e-12, 4.6109187343268406e-12, 4.5463612138862965e-12, 4.5668604585491488e-12, 4.4389980212444777e-12, 4.6717763074743955e-12, 4.4868169950251782e-12, 4.5458919101237779e-12, 4.6744390837238913e-12, 4.5878205887084354e-12, 4.6215837157248528e-12, 4.5089565074707409e-12, 4.4200434423657952e-12, 4.5651481678232743e-12, 4.5682905201738232e-12, 4.5480212609860795e-12, 4.7546478809668004e-12, 4.5842911890192629e-12, 4.4077445138235307e-12, 4.4577634250586585e-12, 4.33113917577832e-12, 4.6319624948110151e-12, 4.5047710728329801e-12, 4.7335921050939424e-12, 4.4769184158466312e-12, 4.7486645039784837e-12, 4.5692593791946126e-12, 4.5053929441374315e-12, 4.5162810616283803e-12, 4.6699867285726614e-12, 4.6369881469277011e-12, 4.7056335626682877e-12, 4.4520680864135186e-12, 4.6 ...
# Errors with first
# [9.4990071364264848e-15, 7.9905658478818248e-15, 7.5202163940524254e-15, 7.5530554033420571e-15, 8.6237322838300654e-15, 8.1457389444761221e-15, 1.2790266762374714e-14, 7.6027122097865891e-15, 9.16283715568511e-15, 8.010858643103802e-15, 8.0646871125633619e-15, 1.6021400178756195e-14, 8.0201276175806418e-15, 8.6253303110961349e-15, 9.4209424983393578e-15, 7.479881991567794e-15, 9.0311397249465132e-15, 1.1141129685476869e-14, 1.1118038434343447e-14, 7.7473916171300068e-15, 1.1664377796982705e-14, 9.6404148552942111e-15, 8.6136819898996463e-15, 1.1038415320685502e-14, 7.9688762533169914e-15, 7.307792565525162e-15, 1.0002383643570312e-14, 9.9312766344006327e-15, 7.7640407991630404e-15, 6.683666120554932e-15, 9.4484593760046923e-15, 7.484810687907739e-15, 8.6076624994380063e-15, 8.4005705169865047e-15, 7.7234704742856769e-15, 1.0040871606387113e-14, 8.8147530941107275e-15, 8.3927385874371647e-15, 6.7758604282985859e-15, 1.0437525843620676e-14, 8.1614805191865252e-15, 9.14820233455238e-15, 7.7244259599762449e-15, 6.4816964295832947e-15, 7.7203257675684251e-15, 8.3169089670764869e-15, 7.4743530809051602e-15, 1.1295209906281301e-14, 8.7922648328575545e-15, 9.4643813619565974e-15, 7.7943582144079925e-15, 6.7528850566933586e-15, 9.9747203552436054e-15, 1.0621561269408275e-14, 1.7891332165786976e-14, 9.4072818979107348e-15, 1.2096600804367697e-14, 8.3834841846375243e-15, 7.3142519818603097e-15, 9.0169087474389901e-15, 1.5391946051046547e-14, 7.6223596878755025e-15, 8.0819566317114068e-15, 9.0475245351218095e-15, 6.8378601392193869e-15, 8.2150945768244561e-15, 9.4521161730920517e-15, 7.526237966182236e-15, 7.9515241613314918e-15, 9.0417735798542512e-15, 7.8896493505009598e-15, 9.339901074767454e-15, 9.1941648738824714e-15, 9.2354672520666979e-15, 8.1528138407005465e-15, 7.6410461291587245e-15, 7.351616537754068e-15, 6.4532892918300892e-15, 7.0048321310078876e-15, 7.2659690764087519e-15, 7.5238218433248962e-15, 8.6118799591528011e-15, 6.491220061466407e-15, 6.918744049899672e-15, 9.9335741021722155e-15, 1.1000322180931832e-14, 8.764838854702362e-15, 7.5233028140608833e-15, 8.8471840964388093e-15, 8.8256485453186434e-15, 7.7394979314249218e-15, 8.4569587444072171e-15, 1.0457308630140716e-14, 1.1701583452206066e-14, 8.5534440641410469e-15, 1.3338163212806009e-14, 1.0076722789520432e-14, 7.5133191335119422e-15, 6.6649373520188957e-15, 7.3370032271924394e-15, 6.6017538657980879e-15, 6.8639573191919825e-15, 7.7327311220898309e-15, 7.2612929558069088e-15, 1.0200432859486241e-14, 1.3775049850783816e-14, 1.1032803143296022e-14, 9.8667005121733093e-15, 9.9843661116594258e-15, 9.3948411550304201e-15, 7.9283427045773174e-15, 1.1607824423887081e-14, 1.2905652241324006e-14, 6.2255291199964093e-15, 1.4956746952066169e-14, 1.1606639260808293e-14, 5.4232611457205592e-15, 9.2507349003234648e-15, 9.1960411507940871e-15, 9.7215298311414952e-15, 7.9386913709456054e-15, 6.889513959329463e-15, 1.1750317385761378e-14, 1.1865056159798826e-14, 1.0227742958113239e-14, 1.1042795844407039e-14, 6.6393245068407935e-15, 1.1733022192705889e-14, 9.0329806134992199e-15, 1.14894774250196e-14, 1.3452530062130208e-14, 9.7447522273697019e-15, 8.3700490982607784e-15, 6.8886271686885438e-15, 7.4794344329109923e-15, 1.1109123343455707e-14, 6.9126322721491104e-15, 8.7094227663175876e-15, 1.3296860140732392e-14, 7.9153038290424861e-15, 1.2274915112131524e-14, 7.1975474191798845e-15, 9.4433579012065392e-15, 7.6710263141599462e-15, 8.1150364206195036e-15, 1.417055153773994e-14, 9.7766968132351188e-15, 8.8052141966610257e-15, 7.5883486994055e-15, 1.1366824842484746e-14, 7.9001943875667281e-15, 9.8266519921175181e-15, 1.0291466290279772e-14, 8.4351331475218665e-15, 7.6839035134668159e-15, 8.3940000783488955e-15, 9.0587218282145438e-15, 8.9620075249818857e-15, 6.4401588228957249e-15, 8.75988101500802e-15, 9.176505388897027e-15, 1.2849159236605345e-14, 8.6088476625167943e-15, 1.5104168610280411e-14, 1.0066923683549333e-14, 6.8321973079044081e-15, 9.4570060116261351e-15, 7.11504397066242 ...

# %%
# Initialize
t0 = 0.03 # 30 ms
system = System(t0)

# ppm, step size for alpha, duration in seconds
system.create_graph_diff_alpha(alpha_ppm, 10.0**(-6), 50, frequency, real_model=True, beta=0.000000003, distance=2.2)
